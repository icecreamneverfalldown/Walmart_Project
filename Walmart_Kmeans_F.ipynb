# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.utils import resample

from sklearn.model_selection import StratifiedKFold, cross_val_score
import matplotlib
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
with open("census-bureau.columns", "r") as f:
    columns = [line.strip() for line in f.readlines() if line.strip()]

df = pd.read_csv("census-bureau.data", header=None, names=columns)

df.to_csv('df.csv', index=False)

df.shape

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199523 entries, 0 to 199522
# Data columns (total 42 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   age                                         199523 non-null  int64
#  1   class of worker                             199523 non-null  object
#  2   detailed industry recode                    199523 non-null  int64
#  3   detailed occupation recode                  199523 non-null  int64
#  4   education                                   199523 non-null  object
#  5   wage per hour                               199523 non-null  int64
#  6   enroll in edu inst last wk                  199523 non-null  object
#  7   marital stat                                199523 non-null  object
#  8   major industry code                         199523 non-null  object
#  9   major occupation code                       199523 non-null  object
#  10  race                                        199523 non-null  object
#  11  hispanic origin                             198649 non-null  object
#  12  sex                                         199523 non-null  object
#  13  member of a labor union                     199523 non-null  object
#  14  reason for unemployment                     199523 non-null  object
#  15  full or part time employment stat           199523 non-null  object
#  16  capital gains                               199523 non-null  int64
#  17  capital losses                              199523 non-null  int64
#  18  dividends from stocks                       199523 non-null  int64
#  19  tax filer stat                              199523 non-null  object
#  20  region of previous residence                199523 non-null  object
#  21  state of previous residence                 199523 non-null  object
#  22  detailed household and family stat          199523 non-null  object
#  23  detailed household summary in household     199523 non-null  object
#  24  weight                                      199523 non-null  float64
#  25  migration code-change in msa                199523 non-null  object
#  26  migration code-change in reg                199523 non-null  object
#  27  migration code-move within reg              199523 non-null  object
#  28  live in this house 1 year ago               199523 non-null  object
#  29  migration prev res in sunbelt               199523 non-null  object
#  30  num persons worked for employer             199523 non-null  int64
#  31  family members under 18                     199523 non-null  object
#  32  country of birth father                     199523 non-null  object
#  33  country of birth mother                     199523 non-null  object
#  34  country of birth self                       199523 non-null  object
#  35  citizenship                                 199523 non-null  object
#  36  own business or self employed               199523 non-null  int64
#  37  fill inc questionnaire for veteran's admin  199523 non-null  object
#  38  veterans benefits                           199523 non-null  int64
#  39  weeks worked in year                        199523 non-null  int64
#  40  year                                        199523 non-null  int64
#  41  label                                       199523 non-null  object
# dtypes: float64(1), int64(12), object(29)
# memory usage: 63.9+ MB

# %%
df = df.replace('?', np.nan)
df = df.fillna("Missing")

# %%
#Correct the data type 
needtype_change = ["detailed industry recode", "detailed occupation recode", "own business or self employed", "veterans benefits", "year"]
df[needtype_change] = df[needtype_change].astype("object")

# Continuous variables: numeric types
continuous_vars = df.select_dtypes(include=["int64", "float64"]).columns.tolist()

# Categorical variables: object types
categorical_vars = df.select_dtypes(include=["object"]).columns.tolist()

print("Continuous variables:", continuous_vars)
print("Categorical variables:", categorical_vars)
# Out:
# Continuous variables: ['age', 'wage per hour', 'capital gains', 'capital losses', 'dividends from stocks', 'weight', 'num persons worked for employer', 'weeks worked in year']
# Categorical variables: ['class of worker', 'detailed industry recode', 'detailed occupation recode', 'education', 'enroll in edu inst last wk', 'marital stat', 'major industry code', 'major occupation code', 'race', 'hispanic origin', 'sex', 'member of a labor union', 'reason for unemployment', 'full or part time employment stat', 'tax filer stat', 'region of previous residence', 'state of previous residence', 'detailed household and family stat', 'detailed household summary in household', 'migration code-change in msa', 'migration code-change in reg', 'migration code-move within reg', 'live in this house 1 year ago', 'migration prev res in sunbelt', 'family members under 18', 'country of birth father', 'country of birth mother', 'country of birth self', 'citizenship', 'own business or self employed', "fill inc questionnaire for veteran's admin", 'veterans benefits', 'year', 'label']

# %%
#processing data 
continuous_vars.remove('weight')
categorical_vars.remove('year')
categorical_vars.remove('label')

# %%
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer

preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), continuous_vars),
        ('cat', OneHotEncoder(drop='first'), categorical_vars)])

X_processed = preprocessor.fit_transform(df)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import silhouette_score

scores = []
for k in range(2, 8):
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=3, max_iter=100, tol=1e-3)
    labels = kmeans.fit_predict(X_processed)
    score = silhouette_score(X_processed, labels)
    scores.append(score)
    print(f"k={k}: score={score:.3f}")

best_k = range(2, 8)[scores.index(max(scores))]
print(f"best k: {best_k}")
# Out:
# k=2: score=0.153
# k=3: score=0.164
# k=4: score=0.186
# k=5: score=0.182
# k=6: score=0.171
# k=7: score=0.164
# best k: 4

# %%
#however, after invested the k, we would see that k=5 makes more sense and we can merge cluster 0 and 4 as they are all

# %%
kmeans_final = KMeans(n_clusters=5, random_state=42)
clusters = kmeans_final.fit_predict(X_processed)

# %%
df['cluster'] = clusters
df['cluster'] = df['cluster'].replace(0, 1)

# %%
for i in range(1,5):
    mask = df['cluster'] == i
    people_count = df.loc[mask, 'weight'].sum()  
    data_points = mask.sum()
    print(f"Cluster {i}: {data_points} data point, represents {round(people_count)} people in national")
# Out:
# Cluster 1: 52197 data point, represents 92434646 people in national
# Cluster 2: 40200 data point, represents 69121801 people in national
# Cluster 3: 56536 data point, represents 95147356 people in national
# Cluster 4: 50590 data point, represents 90542090 people in national

# %%
numeric_cols = df.select_dtypes(include=['number']).columns
numeric_cols = numeric_cols.drop('cluster')
cluster_means = df.groupby('cluster')[numeric_cols].mean().T
print(cluster_means.round(2))
# Out:
# cluster                                1        2        3        4
# age                                38.22    60.96     8.61    38.54
# wage per hour                     104.56     0.06     0.48   110.14
# capital gains                     708.60   218.31     0.17   809.72
# capital losses                     61.60    24.46     0.60    63.50
# dividends from stocks             185.50   489.69     1.06   197.35
# weight                           1770.88  1719.45  1682.95  1789.72
# num persons worked for employer     3.59     0.13     0.06     3.84
# weeks worked in year               43.75     0.82     0.27    45.32
# w_norm                              0.00     0.00     0.00     0.00

# %%
df_new = df.copy()
df_new["age_band"] = pd.cut(df_new["age"],
        bins=[-1,10,17,24,34,44,54,64,200],
        labels=["<=10", "≤17","18–24","25–34","35–44","45–54","55–64","65+"])
df_new["weeks_band"] = pd.cut(df_new["weeks worked in year"],
        bins=[-0.1, 0, 26, 49, 52],
        labels=["didn’t work","~half year"," more than half year but not full year", "full year"])

# %%
categorical_vars_final = ["age_band", "weeks_band", "label"] + categorical_vars 

for col in categorical_vars_final:
    print(f"\n{col} (% in clusters):")
    pct_table = df_new.groupby('cluster')[col].value_counts(normalize=True).unstack(level=0) * 100
    print(pct_table.round(1))
    print("-" * 50)
# Out:
# age_band (% in clusters):
# cluster      1     2     3     4
# age_band
# <=10       0.0   0.0  61.9   0.0
# ≤17        1.9   0.1  33.6   1.9
# 18–24     14.5   2.4   4.1  13.7
# 25–34     26.6   9.3   0.3  25.9
# 35–44     26.4  10.1   0.0  26.8
# 45–54     18.3   9.6   0.0  19.3
# 55–64      9.2  15.7   0.0   9.5
# 65+        3.1  52.8   0.0   2.9
# --------------------------------------------------
#
# weeks_band (% in clusters):
# cluster                                    1     2     3     4
# weeks_band
# didn’t work                              4.0  94.1  97.4   1.9
# ~half year                              12.1   5.1   2.5  10.8
#  more than half year but not full year  14.1   0.5   0.1  14.3
# full year                               69.7   0.2   0.0  73.0
# --------------------------------------------------
#
# label (% in clusters):
# cluster      1     2      3     4
# label
# - 50000.  89.4  98.3  100.0  87.8
# 50000+.   10.6   1.7    0.0  12.2
# --------------------------------------------------
#
# class of worker (% in clusters):
# cluster                            1     2     3     4
# class of worker
# Federal government               2.7   0.1   0.0   2.9
# Local government                 7.4   0.1   0.1   7.6
# Never worked                     0.0   0.2   0.6   0.0
# Not in universe                  6.4  98.1  98.0   4.1
# Private                         68.2   0.8   1.1  70.2
# Self-employed-incorporated       3.2   0.1   0.0   3.1
# Self-employed-not incorporated   8.0   0.6   0.1   7.8
# State government                 4.0   0.1   0.0   4.2
# Without pay                      0.1   0.0   0.0   0.1
# --------------------------------------------------
#
# detailed industry recode (% in clusters):
# cluster                      1     2     3     4
# detailed industry recode
# 0                          6.4  98.2  98.6   4.1
# 1                          0.7   0.0   0.0   0.8
# 2                          2.0   0.3   0.1   1.9
# 3                          0.6   0.0   NaN   0.5
# 4                          5.6   0.1   0.0   5.9
# 5                          0.5   NaN   0.0   0.6
# 6                          0.6   NaN   NaN   0.5
# 7                          0.4   NaN   NaN   0.4
# 8                          0.5   0.0   0.0   0.5
# 9                          0.9   NaN   NaN   1.0
# 10                         0.0   NaN   NaN   0.0
# 11                         1.7   0.0   0.0   1.7
# 12                         1.3   0.0   0.0   1.3
# 13                         0.9   0.0   NaN   0.9
# 14                         0.3   0.0   NaN   0.3
# 15                         0.5   0.0   0.0   0.4
# 16                         0.5   0.0   0.0   0.5
# 17                         0.2   NaN   NaN   0.1
# 18                         0.5   0.0   0.0   0.4
# 19                         1.3   0.0   0.0   1.3
# 20                         0.0   NaN   NaN   0.0
# 21                         0.5   0.0   0.0   0.6
# 22                         0.9   0.0   0.0   0.9
# 23                         0.5   0.0   0.0   0.5
# 24                         1.5   0.0   0.0   1.4
# 25                         1.0   0.0   0.0   1.1
# 26                         0.1   NaN   NaN   0.1
# 27                         0.6   0.0   0.0   0.7
# 28                         0.2   0.0   NaN   0.1
# 29                         4.0   0.1   0.0   4.1
# 30                         1.1   0.0   0.0   1.2
# 31                         1.1   0.0   0.0   1.1
# 32                         3.4   0.0   0.0   3.6
# 33                        16.3   0.2   0.6  16.2
# 34                         2.6   0.0   0.0   2.8
# 35                         3.2   0.1   0.0   3.3
# 36                         0.9   0.1   0.1   0.8
# 37                         3.7   0.1   0.1   4.0
# 38                         1.5   0.0   0.0   1.6
# 39                         2.7   0.1   0.0   2.9
# 40                         1.6   0.0   0.1   1.5
# 41                         3.8   0.0   0.0   3.9
# 42                         4.4   0.1   0.0   4.6
# 43                         7.8   0.1   0.1   8.2
# 44                         2.4   0.1   0.1   2.4
# 45                         4.1   0.1   0.0   4.5
# 46                         0.2   0.0   0.0   0.2
# 47                         1.5   0.0   0.0   1.6
# 48                         0.6   0.0   0.0   0.7
# 49                         0.5   0.0   0.0   0.7
# 50                         1.6   0.0   0.0   1.7
# 51                         0.0   0.0   0.0   0.0
# --------------------------------------------------
#
# detailed occupation recode (% in clusters):
# cluster                       1     2     3    4
# detailed occupation recode
# 0                           6.4  98.2  98.6  4.1
# 1                           0.5   0.0   NaN  0.5
# 2                           8.2   0.1   0.0  8.8
# 3                           3.0   0.0   NaN  3.2
# 4                           1.3   0.0   0.0  1.4
# 5                           0.8   0.0   NaN  0.9
# 6                           0.5   0.0   NaN  0.4
# 7                           0.7   0.0   NaN  0.8
# 8                           2.0   0.0   0.0  2.2
# 9                           0.7   0.0   0.0  0.8
# 10                          3.5   0.0   0.0  3.6
# 11                          0.6   0.0   NaN  0.7
# 12                          3.1   0.1   0.0  3.3
# 13                          1.2   0.0   NaN  1.2
# 14                          0.9   0.0   0.0  0.9
# 15                          0.8   0.0   0.0  0.8
# 16                          3.4   0.0   NaN  3.3
# 17                          1.6   0.0   0.0  1.8
# 18                          1.0   0.0   NaN  1.1
# 19                          5.1   0.1   0.2  5.2
# 20                          0.1   0.0   NaN  0.1
# 21                          0.5   0.0   NaN  0.5
# 22                          0.4   0.0   NaN  0.4
# 23                          3.2   0.0   0.0  3.3
# 24                          1.8   0.0   0.0  1.8
# 25                          0.7   0.0   0.0  0.8
# 26                          7.6   0.1   0.1  7.6
# 27                          0.7   0.0   0.1  0.7
# 28                          1.6   0.0   0.0  1.6
# 29                          4.8   0.1   0.3  4.7
# 30                          1.8   0.1   0.0  1.8
# 31                          2.5   0.1   0.1  2.6
# 32                          2.2   0.1   0.1  2.3
# 33                          3.2   0.0   0.0  3.3
# 34                          3.8   0.1   0.0  4.0
# 35                          3.1   0.0   0.0  3.1
# 36                          3.9   0.1   0.0  4.1
# 37                          2.1   0.1   0.0  2.2
# 38                          2.9   0.0   0.0  2.9
# 39                          1.0   0.0   0.0  1.0
# 40                          0.5   0.0   0.0  0.6
# 41                          1.6   0.0   0.1  1.4
# 42                          1.8   0.0   0.1  1.8
# 43                          1.3   0.2   0.0  1.2
# 44                          1.5   0.1   0.1  1.5
# 45                          0.2   0.0   0.0  0.2
# 46                          0.0   0.0   0.0  0.0
# --------------------------------------------------
#
# education (% in clusters):
# cluster                                    1     2     3     4
# education
# 10th grade                               3.2   5.9   3.5   3.0
# 11th grade                               3.8   4.5   2.3   3.6
# 12th grade no diploma                    1.3   1.5   0.5   1.0
# 1st 2nd 3rd or 4th grade                 0.7   2.7   0.0   0.7
# 5th or 6th grade                         1.4   4.4   0.1   1.4
# 7th and 8th grade                        2.1  10.9   2.8   2.0
# 9th grade                                2.0   4.5   4.2   2.1
# Associates degree-academic program       3.5   1.7   0.0   3.7
# Associates degree-occup /vocational      4.3   2.3   0.1   4.2
# Bachelors degree(BA AB BS)              15.8   7.9   0.2  16.6
# Children                                 0.0   NaN  83.9   NaN
# Doctorate degree(PhD EdD)                1.0   0.5   NaN   1.1
# High school graduate                    33.1  35.4   0.9  32.4
# Less than 1st grade                      0.2   1.3   0.1   0.2
# Masters degree(MA MS MEng MEd MSW MBA)   5.2   2.5   0.0   5.6
# Prof school degree (MD DDS DVM LLB JD)   1.4   0.6   NaN   1.6
# Some college but no degree              21.1  13.5   1.5  20.8
# --------------------------------------------------
#
# enroll in edu inst last wk (% in clusters):
# cluster                        1     2     3     4
# enroll in edu inst last wk
# College or university        4.5   0.7   1.8   4.1
# High school                  2.5   0.1   7.7   2.5
# Not in universe             93.0  99.3  90.5  93.5
# --------------------------------------------------
#
# marital stat (% in clusters):
# cluster                             1     2     3     4
# marital stat
# Divorced                          9.6   7.2   0.0   9.5
# Married-A F spouse present        0.5   0.4   NaN   0.5
# Married-civilian spouse present  58.7  58.7   0.0  59.3
# Married-spouse absent             1.0   1.2   0.0   1.0
# Never married                    25.9   8.9  99.9  25.5
# Separated                         2.4   2.5   0.0   2.4
# Widowed                           1.9  21.1   0.0   1.9
# --------------------------------------------------
#
# major industry code (% in clusters):
# cluster                                 1     2     3     4
# major industry code
# Agriculture                           2.7   0.3   0.1   2.8
# Armed Forces                          0.0   0.0   0.0   0.0
# Business and repair services          5.3   0.1   0.1   5.5
# Communications                        1.1   0.0   0.0   1.2
# Construction                          5.6   0.1   0.0   5.9
# Education                             7.8   0.1   0.1   8.2
# Entertainment                         1.6   0.0   0.1   1.5
# Finance insurance and real estate     5.9   0.1   0.0   6.0
# Forestry and fisheries                0.2   0.0   0.0   0.2
# Hospital services                     3.8   0.0   0.0   3.9
# Manufacturing-durable goods           8.8   0.1   0.0   8.6
# Manufacturing-nondurable goods        6.6   0.1   0.0   6.7
# Medical except hospital               4.4   0.1   0.0   4.6
# Mining                                0.6   0.0   NaN   0.5
# Not in universe or children           6.4  98.2  98.6   4.1
# Other professional services           4.1   0.1   0.0   4.5
# Personal services except private HH   2.7   0.1   0.0   2.9
# Private household services            0.9   0.1   0.1   0.8
# Public administration                 4.2   0.1   0.0   4.6
# Retail trade                         16.3   0.2   0.6  16.2
# Social services                       2.4   0.1   0.1   2.4
# Transportation                        4.0   0.1   0.0   4.1
# Utilities and sanitary services       1.1   0.0   0.0   1.1
# Wholesale trade                       3.4   0.0   0.0   3.6
# --------------------------------------------------
#
# major occupation code (% in clusters):
# cluster                                   1     2     3     4
# major occupation code
# Adm support including clerical         14.2   0.2   0.1  14.4
# Armed Forces                            0.0   0.0   0.0   0.0
# Executive admin and managerial         11.7   0.1   0.0  12.5
# Farming forestry and fishing            2.9   0.3   0.1   2.8
# Handlers equip cleaners etc             3.9   0.1   0.2   3.8
# Machine operators assmblrs & inspctrs   6.1   0.1   0.0   6.2
# Not in universe                         6.4  98.2  98.6   4.1
# Other service                          11.4   0.3   0.5  11.4
# Precision production craft & repair    10.0   0.1   0.0  10.3
# Private household services              0.7   0.0   0.1   0.7
# Professional specialty                 13.0   0.2   0.1  13.9
# Protective services                     1.6   0.0   0.0   1.6
# Sales                                  11.1   0.1   0.2  11.5
# Technicians and related support         2.9   0.0   0.0   2.9
# Transportation and material moving      3.9   0.1   0.0   3.8
# --------------------------------------------------
#
# race (% in clusters):
# cluster                         1     2     3     4
# race
# Amer Indian Aleut or Eskimo   1.0   0.9   1.6   1.0
# Asian or Pacific Islander     2.5   2.6   3.3   3.2
# Black                         8.8   9.3  13.6   8.7
# Other                         1.1   1.2   2.7   2.1
# White                        86.6  86.0  78.8  85.0
# --------------------------------------------------
#
# hispanic origin (% in clusters):
# cluster                       1     2     3     4
# hispanic origin
# All other                  87.3  87.9  82.2  88.0
# Central or South American   2.0   1.5   2.2   1.9
# Chicano                     0.1   0.1   0.2   0.1
# Cuban                       0.5   0.9   0.4   0.6
# Do not know                 0.2   0.2   0.1   0.1
# Mexican (Mexicano)          3.4   3.5   3.8   3.8
# Mexican-American            3.2   2.5   6.9   3.0
# Missing                     0.7   0.5   0.4   0.2
# Other Spanish               1.2   1.3   1.4   1.1
# Puerto Rican                1.3   1.8   2.3   1.3
# --------------------------------------------------
#
# sex (% in clusters):
# cluster     1     2     3     4
# sex
# Female   48.0  67.3  49.3  47.5
# Male     52.0  32.7  50.7  52.5
# --------------------------------------------------
#
# member of a labor union (% in clusters):
# cluster                     1      2     3     4
# member of a labor union
# No                       15.3    0.0   0.1  15.8
# Not in universe          81.8  100.0  99.9  81.3
# Yes                       3.0    0.0   NaN   2.9
# --------------------------------------------------
#
# reason for unemployment (% in clusters):
# cluster                     1     2     3     4
# reason for unemployment
# Job leaver                0.6   0.0   0.0   0.6
# Job loser - on layoff     0.9   0.1   0.0   0.9
# New entrant               0.0   0.2   0.6   0.0
# Not in universe          94.3  99.2  99.1  95.5
# Other job loser           2.2   0.2   0.0   1.6
# Re-entrant                1.9   0.4   0.2   1.4
# --------------------------------------------------
#
# full or part time employment stat (% in clusters):
# cluster                                 1     2     3     4
# full or part time employment stat
# Children or Armed Forces            100.0  48.1  91.7   0.7
# Full-time schedules                   NaN   0.4   0.4  79.8
# Not in labor force                    NaN  50.8   7.3   4.5
# PT for econ reasons usually FT        NaN   0.0   0.0   1.0
# PT for econ reasons usually PT        NaN   0.0   0.0   2.4
# PT for non-econ reasons usually FT    NaN   0.1   0.0   6.4
# Unemployed full-time                  NaN   0.4   0.2   4.0
# Unemployed part- time                 NaN   0.1   0.3   1.2
# --------------------------------------------------
#
# tax filer stat (% in clusters):
# cluster                          1     2     3     4
# tax filer stat
# Head of household              6.7   1.2   0.0   6.9
# Joint both 65+                 1.3  17.6   NaN   1.1
# Joint both under 65           55.8  24.0   0.0  56.6
# Joint one under 65 & one 65+   1.6   5.4   0.0   1.7
# Nonfiler                       4.6  37.7  99.2   2.9
# Single                        30.0  14.1   0.8  30.8
# --------------------------------------------------
#
# region of previous residence (% in clusters):
# cluster                          1     2     3      4
# region of previous residence
# Abroad                         0.5   0.3   0.3    NaN
# Midwest                        4.5   0.6   1.7    NaN
# Northeast                      3.4   0.6   1.2    NaN
# Not in universe               80.5  96.6  92.5  100.0
# South                          6.0   1.0   2.4    NaN
# West                           5.0   0.8   2.0    NaN
# --------------------------------------------------
#
# state of previous residence (% in clusters):
# cluster                         1     2     3      4
# state of previous residence
# Abroad                        0.6   0.3   0.4    NaN
# Alabama                       0.3   0.1   0.1    NaN
# Alaska                        0.4   0.0   0.2    NaN
# Arizona                       0.3   0.1   0.1    NaN
# Arkansas                      0.3   0.0   0.1    NaN
# California                    2.1   0.3   0.9    NaN
# Colorado                      0.3   0.1   0.1    NaN
# Connecticut                   0.1   0.0   0.1    NaN
# Delaware                      0.1   0.0   0.0    NaN
# District of Columbia          0.2   0.0   0.1    NaN
# Florida                       1.0   0.2   0.4    NaN
# Georgia                       0.3   0.0   0.1    NaN
# Idaho                         0.0   0.0   0.0    NaN
# Illinois                      0.2   0.0   0.1    NaN
# Indiana                       0.7   0.1   0.2    NaN
# Iowa                          0.2   0.0   0.1    NaN
# Kansas                        0.2   0.0   0.1    NaN
# Kentucky                      0.3   0.0   0.1    NaN
# Louisiana                     0.2   0.1   0.1    NaN
# Maine                         0.2   0.0   0.1    NaN
# Maryland                      0.2   0.0   0.1    NaN
# Massachusetts                 0.2   0.0   0.1    NaN
# Michigan                      0.6   0.1   0.2    NaN
# Minnesota                     0.7   0.1   0.3    NaN
# Missing                       0.9   0.1   0.3    NaN
# Mississippi                   0.3   0.0   0.1    NaN
# Missouri                      0.2   0.0   0.1    NaN
# Montana                       0.3   0.0   0.1    NaN
# Nebraska                      0.2   0.0   0.1    NaN
# Nevada                        0.2   0.0   0.1    NaN
# New Hampshire                 0.3   0.1   0.1    NaN
# New Jersey                    0.1   0.0   0.0    NaN
# New Mexico                    0.6   0.1   0.2    NaN
# New York                      0.2   0.0   0.1    NaN
# North Carolina                1.0   0.2   0.4    NaN
# North Dakota                  0.6   0.1   0.2    NaN
# Not in universe              80.5  96.6  92.5  100.0
# Ohio                          0.3   0.1   0.1    NaN
# Oklahoma                      0.8   0.1   0.3    NaN
# Oregon                        0.3   0.0   0.1    NaN
# Pennsylvania                  0.3   0.1   0.1    NaN
# South Carolina                0.1   0.0   0.0    NaN
# South Dakota                  0.2   0.0   0.1    NaN
# Tennessee                     0.2   0.0   0.1    NaN
# Texas                         0.3   0.1   0.1    NaN
# Utah                          1.3   0.2   0.6    NaN
# Vermont                       0.2   0.0   0.1    NaN
# Virginia                      0.2   0.0   0.0    NaN
# West Virginia                 0.3   0.0   0.1    NaN
# Wisconsin                     0.1   0.0   0.1    NaN
# Wyoming                       0.3   0.0   0.1    NaN
# --------------------------------------------------
#
# detailed household and family stat (% in clusters):
# cluster                                             1     2     3     4
# detailed household and family stat
# Child 18+ ever marr Not in a subfamily            0.8   0.6   0.0   0.7
# Child 18+ ever marr RP of subfamily               0.5   0.4   0.0   0.5
# Child 18+ never marr Not in a subfamily           9.5   1.7   3.3   8.9
# Child 18+ never marr RP of subfamily              0.4   0.2   0.2   0.4
# Child 18+ spouse of subfamily RP                  0.1   0.1   NaN   0.1
# Child <18 ever marr RP of subfamily               0.0   0.0   0.0   0.0
# Child <18 ever marr not in subfamily              0.0   NaN   0.1   0.0
# Child <18 never marr RP of subfamily              0.0   NaN   0.1   0.0
# Child <18 never marr not in subfamily             1.6   NaN  86.0   1.7
# Child <18 spouse of subfamily RP                  NaN   0.0   NaN   NaN
# Child under 18 of RP of unrel subfamily           0.0   NaN   1.2   0.0
# Grandchild 18+ ever marr RP of subfamily          0.0   0.0   NaN   0.0
# Grandchild 18+ ever marr not in subfamily         0.0   0.0   NaN   0.0
# Grandchild 18+ never marr RP of subfamily         0.0   NaN   0.0   0.0
# Grandchild 18+ never marr not in subfamily        0.3   0.0   0.2   0.2
# Grandchild 18+ spouse of subfamily RP             0.0   0.0   NaN   0.0
# Grandchild <18 ever marr not in subfamily         0.0   NaN   NaN   NaN
# Grandchild <18 never marr RP of subfamily         NaN   NaN   0.0   NaN
# Grandchild <18 never marr child of subfamily RP   0.0   NaN   3.3   0.0
# Grandchild <18 never marr not in subfamily        0.0   NaN   1.8   0.0
# Householder                                      39.2  32.2   0.1  39.1
# In group quarters                                 0.1   0.1   0.1   0.1
# Nonfamily householder                            12.5  22.6   0.0  13.0
# Other Rel 18+ ever marr RP of subfamily           0.4   0.6   NaN   0.4
# Other Rel 18+ ever marr not in subfamily          0.5   3.5   NaN   0.6
# Other Rel 18+ never marr RP of subfamily          0.1   0.0   0.0   0.1
# Other Rel 18+ never marr not in subfamily         1.2   0.9   0.3   1.2
# Other Rel 18+ spouse of subfamily RP              0.4   0.5   NaN   0.4
# Other Rel <18 ever marr RP of subfamily           0.0   0.0   NaN   0.0
# Other Rel <18 ever marr not in subfamily          NaN   NaN   0.0   NaN
# Other Rel <18 never marr child of subfamily RP    0.0   NaN   1.1   0.0
# Other Rel <18 never marr not in subfamily         0.0   NaN   1.0   0.0
# Other Rel <18 never married RP of subfamily       NaN   NaN   0.0   NaN
# Other Rel <18 spouse of subfamily RP              0.0   0.0   NaN   NaN
# RP of unrelated subfamily                         0.6   0.2   0.1   0.4
# Secondary individual                              4.6   1.7   1.1   4.8
# Spouse of RP of unrelated subfamily               0.0   0.0   NaN   0.0
# Spouse of householder                            26.8  34.6   0.0  27.2
# --------------------------------------------------
#
# detailed household summary in household (% in clusters):
# cluster                                     1     2     3     4
# detailed household summary in household
# Child 18 or older                        11.3   2.9   3.5  10.6
# Child under 18 ever married               0.0   0.0   0.1   0.0
# Child under 18 never married              1.6   NaN  86.2   1.7
# Group Quarters- Secondary individual      0.1   0.1   0.0   0.0
# Householder                              51.8  54.8   0.1  52.1
# Nonrelative of householder                5.3   1.9   2.4   5.3
# Other relative of householder             3.1   5.6   7.7   3.0
# Spouse of householder                    26.8  34.6   0.0  27.3
# --------------------------------------------------
#
# migration code-change in msa (% in clusters):
# cluster                          1     2     3      4
# migration code-change in msa
# Abroad to MSA                  0.4   0.3   0.2    NaN
# Abroad to nonMSA               0.1   0.0   0.0    NaN
# MSA to MSA                    13.6   1.8   4.9    NaN
# MSA to nonMSA                  0.9   0.3   0.4    NaN
# Missing                        NaN  51.9  49.9  100.0
# NonMSA to MSA                  0.8   0.2   0.3    NaN
# NonMSA to nonMSA               3.3   0.7   1.4    NaN
# Nonmover                      80.5  44.7  39.8    NaN
# Not identifiable               0.5   0.1   0.3    NaN
# Not in universe                NaN   NaN   2.7    NaN
# --------------------------------------------------
#
# migration code-change in reg (% in clusters):
# cluster                            1     2     3      4
# migration code-change in reg
# Abroad                           0.5   0.3   0.3    NaN
# Different county same state      3.5   0.7   1.3    NaN
# Different division same region   0.5   0.2   0.2    NaN
# Different region                 1.4   0.4   0.6    NaN
# Different state same division    1.1   0.4   0.5    NaN
# Missing                          NaN  51.9  49.9  100.0
# Nonmover                        80.5  44.7  39.8    NaN
# Not in universe                  NaN   NaN   2.7    NaN
# Same county                     12.5   1.5   4.7    NaN
# --------------------------------------------------
#
# migration code-move within reg (% in clusters):
# cluster                            1     2     3      4
# migration code-move within reg
# Abroad                           0.5   0.3   0.3    NaN
# Different county same state      3.5   0.7   1.3    NaN
# Different state in Midwest       0.7   0.2   0.3    NaN
# Different state in Northeast     0.5   0.1   0.2    NaN
# Different state in South         1.1   0.3   0.5    NaN
# Different state in West          0.7   0.3   0.3    NaN
# Missing                          NaN  51.9  49.9  100.0
# Nonmover                        80.5  44.7  39.8    NaN
# Not in universe                  NaN   NaN   2.7    NaN
# Same county                     12.5   1.5   4.7    NaN
# --------------------------------------------------
#
# live in this house 1 year ago (% in clusters):
# cluster                              1     2     3      4
# live in this house 1 year ago
# No                                19.5   3.4   7.5    NaN
# Not in universe under 1 year old   NaN  51.9  52.6  100.0
# Yes                               80.5  44.7  39.8    NaN
# --------------------------------------------------
#
# migration prev res in sunbelt (% in clusters):
# cluster                           1     2     3      4
# migration prev res in sunbelt
# Missing                         NaN  51.9  49.9  100.0
# No                             12.4   2.2   4.6    NaN
# Not in universe                80.5  44.7  42.5    NaN
# Yes                             7.0   1.2   2.9    NaN
# --------------------------------------------------
#
# family members under 18 (% in clusters):
# cluster                     1      2     3     4
# family members under 18
# Both parents present      1.3    NaN  66.6   1.3
# Father only present       0.1    NaN   3.2   0.1
# Mother only present       0.4    NaN  22.0   0.3
# Neither parent present    0.1    NaN   2.8   0.1
# Not in universe          98.2  100.0   5.4  98.2
# --------------------------------------------------
#
# country of birth father (% in clusters):
# cluster                          1     2     3     4
# country of birth father
# Cambodia                       0.1   0.1   0.1   0.1
# Canada                         0.7   1.3   0.2   0.7
# China                          0.5   0.5   0.3   0.5
# Columbia                       0.3   0.3   0.3   0.3
# Cuba                           0.5   0.7   0.5   0.6
# Dominican-Republic             0.5   0.6   1.0   0.4
# Ecuador                        0.2   0.2   0.2   0.2
# El-Salvador                    0.5   0.3   0.6   0.5
# England                        0.4   0.8   0.2   0.3
# France                         0.1   0.2   0.1   0.1
# Germany                        0.5   1.6   0.3   0.6
# Greece                         0.2   0.3   0.1   0.2
# Guatemala                      0.3   0.1   0.3   0.2
# Haiti                          0.2   0.1   0.2   0.2
# Holand-Netherlands             NaN   0.0   0.0   0.1
# Honduras                       0.1   0.1   0.1   0.1
# Hong Kong                      0.0   0.0   0.1   0.1
# Hungary                        0.1   0.5   0.0   0.1
# India                          0.3   0.2   0.3   0.3
# Iran                           0.1   0.1   0.1   0.1
# Ireland                        0.2   0.6   0.0   0.2
# Italy                          0.9   3.1   0.2   0.7
# Jamaica                        0.2   0.1   0.3   0.3
# Japan                          0.1   0.4   0.1   0.2
# Laos                           0.0   0.1   0.1   0.1
# Mexico                         4.2   4.4   6.7   4.4
# Missing                        2.9   6.2   2.2   2.9
# Nicaragua                      0.2   0.1   0.2   0.2
# Outlying-U S (Guam USVI etc)   0.1   0.1   0.1   0.1
# Panama                         NaN   0.0   0.0   0.0
# Peru                           0.2   0.2   0.2   0.2
# Philippines                    0.5   0.3   0.6   0.8
# Poland                         0.4   1.7   0.1   0.5
# Portugal                       0.2   0.3   0.1   0.2
# Puerto-Rico                    1.1   1.7   1.5   1.1
# Scotland                       0.1   0.2   0.0   0.1
# South Korea                    0.2   0.3   0.3   0.3
# Taiwan                         0.1   0.1   0.1   0.1
# Thailand                       0.0   0.1   0.1   0.1
# Trinadad&Tobago                0.0   0.0   0.1   0.0
# United-States                 82.3  71.6  81.5  81.8
# Vietnam                        0.2   0.2   0.3   0.2
# Yugoslavia                     0.1   0.3   0.0   0.1
# --------------------------------------------------
#
# country of birth mother (% in clusters):
# cluster                          1     2     3     4
# country of birth mother
# Cambodia                       0.1   0.1   0.1   0.0
# Canada                         0.8   1.3   0.3   0.8
# China                          0.4   0.4   0.2   0.4
# Columbia                       0.3   0.3   0.3   0.3
# Cuba                           0.5   0.8   0.4   0.6
# Dominican-Republic             0.4   0.5   0.8   0.4
# Ecuador                        0.2   0.2   0.2   0.2
# El-Salvador                    0.6   0.4   0.7   0.5
# England                        0.5   0.7   0.2   0.5
# France                         0.1   0.2   0.1   0.1
# Germany                        0.6   1.4   0.3   0.6
# Greece                         0.1   0.2   0.1   0.1
# Guatemala                      0.3   0.1   0.3   0.2
# Haiti                          0.2   0.1   0.2   0.2
# Holand-Netherlands             NaN   0.0   0.0   0.1
# Honduras                       0.1   0.1   0.1   0.1
# Hong Kong                      0.0   0.0   0.1   0.1
# Hungary                        0.1   0.4   0.0   0.1
# India                          0.3   0.2   0.3   0.3
# Iran                           0.1   0.1   0.1   0.1
# Ireland                        0.3   0.7   0.0   0.3
# Italy                          0.7   2.7   0.2   0.6
# Jamaica                        0.2   0.2   0.2   0.3
# Japan                          0.2   0.4   0.2   0.2
# Laos                           0.0   0.1   0.1   0.1
# Mexico                         4.2   4.3   6.4   4.4
# Missing                        2.6   5.6   2.1   2.7
# Nicaragua                      0.1   0.1   0.2   0.2
# Outlying-U S (Guam USVI etc)   0.1   0.1   0.1   0.1
# Panama                         NaN   0.0   0.0   0.0
# Peru                           0.2   0.2   0.2   0.2
# Philippines                    0.6   0.3   0.7   0.8
# Poland                         0.4   1.5   0.1   0.4
# Portugal                       0.2   0.3   0.1   0.2
# Puerto-Rico                    1.1   1.6   1.2   1.1
# Scotland                       0.1   0.2   0.0   0.1
# South Korea                    0.2   0.3   0.4   0.3
# Taiwan                         0.1   0.1   0.2   0.1
# Thailand                       0.1   0.1   0.1   0.1
# Trinadad&Tobago                0.0   0.0   0.1   0.0
# United-States                 82.6  73.2  82.2  82.0
# Vietnam                        0.2   0.2   0.3   0.2
# Yugoslavia                     0.1   0.2   0.0   0.1
# --------------------------------------------------
#
# country of birth self (% in clusters):
# cluster                          1     2     3     4
# country of birth self
# Cambodia                       0.1   0.1   0.0   0.0
# Canada                         0.3   0.6   0.1   0.4
# China                          0.3   0.4   0.1   0.3
# Columbia                       0.3   0.3   0.1   0.2
# Cuba                           0.4   0.8   0.0   0.5
# Dominican-Republic             0.3   0.5   0.3   0.3
# Ecuador                        0.2   0.2   0.0   0.2
# El-Salvador                    0.5   0.3   0.2   0.4
# England                        0.3   0.4   0.1   0.3
# France                         0.1   0.1   0.0   0.1
# Germany                        0.5   0.7   0.3   0.4
# Greece                         0.1   0.1   0.0   0.1
# Guatemala                      0.3   0.1   0.1   0.2
# Haiti                          0.1   0.1   0.1   0.2
# Holand-Netherlands             NaN   0.0   0.0   0.0
# Honduras                       0.1   0.1   0.0   0.1
# Hong Kong                      0.1   0.0   0.0   0.1
# Hungary                        0.0   0.1   0.0   0.0
# India                          0.3   0.2   0.1   0.3
# Iran                           0.1   0.1   0.0   0.1
# Ireland                        0.1   0.1   0.0   0.1
# Italy                          0.2   0.5   0.0   0.2
# Jamaica                        0.2   0.1   0.1   0.3
# Japan                          0.2   0.2   0.1   0.2
# Laos                           0.0   0.1   0.0   0.1
# Mexico                         3.3   3.4   1.7   3.5
# Missing                        1.9   2.4   0.8   2.0
# Nicaragua                      0.1   0.1   0.1   0.1
# Outlying-U S (Guam USVI etc)   0.1   0.1   0.0   0.1
# Panama                         NaN   0.0   0.0   0.0
# Peru                           0.2   0.2   0.1   0.2
# Philippines                    0.5   0.3   0.2   0.7
# Poland                         0.2   0.4   0.0   0.2
# Portugal                       0.1   0.1   0.0   0.1
# Puerto-Rico                    0.7   1.3   0.4   0.7
# Scotland                       0.0   0.1   0.0   0.0
# South Korea                    0.2   0.3   0.2   0.3
# Taiwan                         0.1   0.1   0.1   0.1
# Thailand                       0.0   0.1   0.1   0.1
# Trinadad&Tobago                0.0   0.0   0.0   0.0
# United-States                 87.4  84.7  94.4  86.8
# Vietnam                        0.2   0.2   0.2   0.2
# Yugoslavia                     0.0   0.1   0.0   0.0
# --------------------------------------------------
#
# citizenship (% in clusters):
# cluster                                         1     2     3     4
# citizenship
# Foreign born- Not a citizen of U S            7.4   8.3   4.0   7.8
# Foreign born- U S citizen by naturalization   3.4   4.9   0.4   3.7
# Native- Born abroad of American Parent(s)     1.1   0.7   0.7   1.0
# Native- Born in Puerto Rico or U S Outlying   0.7   1.3   0.4   0.7
# Native- Born in the United States            87.4  84.7  94.4  86.8
# --------------------------------------------------
#
# own business or self employed (% in clusters):
# cluster                           1     2     3     4
# own business or self employed
# 0                              82.7  99.5  99.8  81.3
# 1                               2.3   0.1   0.0   2.9
# 2                              15.0   0.4   0.2  15.9
# --------------------------------------------------
#
# fill inc questionnaire for veteran's admin (% in clusters):
# cluster                                        1     2      3     4
# fill inc questionnaire for veteran's admin
# No                                           0.7   2.2    0.0   0.7
# Not in universe                             99.3  97.0  100.0  99.2
# Yes                                          0.1   0.8    0.0   0.1
# --------------------------------------------------
#
# veterans benefits (% in clusters):
# cluster               1     2     3     4
# veterans benefits
# 0                   NaN   NaN  83.9   NaN
# 1                   0.7   3.0   0.0   0.8
# 2                  99.3  97.0  16.1  99.2
# --------------------------------------------------

# %%
#weighted within group
for col in categorical_vars_final:
    print(f"\n{col} (%):")
    
    df_temp = df_new.copy()
    df_temp['within_cluster_weight_pct'] = df_temp.groupby('cluster')['weight'].transform(lambda x: x / x.sum())
    
    pct_table = pd.crosstab(
        index=df_temp[col],
        columns=df_temp['cluster'], 
        values=df_temp['within_cluster_weight_pct'],
        aggfunc='sum'
    ) * 100
    
    print(pct_table.round(1))
    print("-" * 50)
# Out:
# age_band (%):
# cluster      1     2     3     4
# age_band
# <=10       0.0   0.0  61.7   0.0
# ≤17        1.8   0.1  33.3   1.8
# 18–24     15.4   2.5   4.6  14.5
# 25–34     27.0   9.4   0.4  26.2
# 35–44     26.3  10.5   0.0  26.7
# 45–54     17.7   9.9   0.0  18.7
# 55–64      8.9  16.0   0.0   9.2
# 65+        3.0  51.6   0.0   2.8
# --------------------------------------------------
#
# weeks_band (%):
# cluster                                    1     2     3     4
# weeks_band
# didn’t work                              4.4  94.3  97.4   1.9
# ~half year                              12.3   5.0   2.5  11.1
#  more than half year but not full year  14.0   0.5   0.1  14.3
# full year                               69.3   0.2   0.0  72.6
# --------------------------------------------------
#
# label (%):
# cluster      1     2      3     4
# label
# - 50000.  89.3  98.3  100.0  87.7
# 50000+.   10.7   1.7    0.0  12.3
# --------------------------------------------------
#
# class of worker (%):
# cluster                            1     2     3     4
# class of worker
# Federal government               2.7   0.1   0.0   2.8
# Local government                 7.3   0.1   0.1   7.5
# Never worked                     0.1   0.2   0.6   0.0
# Not in universe                  6.6  98.0  98.0   4.1
# Private                         68.7   0.8   1.1  70.7
# Self-employed-incorporated       3.0   0.1   0.0   3.1
# Self-employed-not incorporated   7.6   0.6   0.1   7.6
# State government                 3.8   0.1   0.0   3.9
# Without pay                      0.1   0.0   0.0   0.1
# --------------------------------------------------
#
# detailed industry recode (%):
# cluster                      1     2     3     4
# detailed industry recode
# 0                          6.7  98.2  98.6   4.2
# 1                          0.8   0.0   0.0   0.9
# 2                          1.7   0.3   0.1   1.7
# 3                          0.5   0.0   NaN   0.5
# 4                          5.6   0.1   0.0   5.9
# 5                          0.5   NaN   0.0   0.6
# 6                          0.6   NaN   NaN   0.6
# 7                          0.4   NaN   NaN   0.5
# 8                          0.6   0.0   0.0   0.6
# 9                          1.0   NaN   NaN   1.0
# 10                         0.0   NaN   NaN   0.0
# 11                         1.8   0.0   0.0   1.8
# 12                         1.3   0.0   0.0   1.4
# 13                         0.9   0.0   NaN   0.9
# 14                         0.4   0.0   NaN   0.3
# 15                         0.5   0.0   0.0   0.4
# 16                         0.5   0.0   0.0   0.5
# 17                         0.2   NaN   NaN   0.1
# 18                         0.4   0.0   0.0   0.4
# 19                         1.3   0.0   0.0   1.3
# 20                         0.0   NaN   NaN   0.0
# 21                         0.5   0.0   0.0   0.6
# 22                         0.9   0.0   0.0   0.9
# 23                         0.5   0.0   0.0   0.5
# 24                         1.5   0.0   0.0   1.5
# 25                         1.0   0.0   0.0   1.0
# 26                         0.1   NaN   NaN   0.1
# 27                         0.5   0.0   0.0   0.7
# 28                         0.1   0.0   NaN   0.1
# 29                         4.0   0.1   0.0   4.1
# 30                         1.1   0.0   0.0   1.2
# 31                         1.1   0.0   0.0   1.2
# 32                         3.4   0.0   0.0   3.6
# 33                        16.4   0.2   0.6  16.3
# 34                         2.7   0.0   0.0   2.8
# 35                         3.3   0.1   0.0   3.3
# 36                         0.8   0.1   0.1   0.8
# 37                         4.1   0.1   0.1   4.2
# 38                         1.6   0.0   0.0   1.6
# 39                         2.6   0.1   0.0   2.7
# 40                         1.6   0.0   0.1   1.5
# 41                         3.8   0.0   0.0   3.7
# 42                         4.3   0.1   0.0   4.6
# 43                         7.6   0.1   0.1   8.0
# 44                         2.2   0.1   0.1   2.3
# 45                         4.2   0.1   0.0   4.5
# 46                         0.1   0.0   0.0   0.1
# 47                         1.6   0.0   0.0   1.7
# 48                         0.5   0.0   0.0   0.7
# 49                         0.6   0.0   0.0   0.7
# 50                         1.5   0.0   0.0   1.6
# 51                         0.0   0.0   0.0   0.0
# --------------------------------------------------
#
# detailed occupation recode (%):
# cluster                       1     2     3    4
# detailed occupation recode
# 0                           6.7  98.2  98.6  4.2
# 1                           0.5   0.0   NaN  0.5
# 2                           8.2   0.1   0.0  8.7
# 3                           3.1   0.0   NaN  3.2
# 4                           1.3   0.0   0.0  1.4
# 5                           0.9   0.0   NaN  0.9
# 6                           0.4   0.0   NaN  0.4
# 7                           0.7   0.0   NaN  0.7
# 8                           2.0   0.0   0.0  2.1
# 9                           0.6   0.0   0.0  0.7
# 10                          3.4   0.0   0.0  3.6
# 11                          0.6   0.0   NaN  0.7
# 12                          3.1   0.1   0.0  3.3
# 13                          1.3   0.0   NaN  1.3
# 14                          0.9   0.0   0.0  0.9
# 15                          0.8   0.0   0.0  0.8
# 16                          3.3   0.0   NaN  3.3
# 17                          1.7   0.0   0.0  1.9
# 18                          1.0   0.0   NaN  1.2
# 19                          5.1   0.1   0.2  5.2
# 20                          0.1   0.0   NaN  0.1
# 21                          0.5   0.0   NaN  0.5
# 22                          0.4   0.0   NaN  0.4
# 23                          3.0   0.0   0.0  3.3
# 24                          1.7   0.0   0.0  1.8
# 25                          0.7   0.0   0.0  0.7
# 26                          7.7   0.1   0.1  7.6
# 27                          0.7   0.0   0.1  0.6
# 28                          1.8   0.0   0.0  1.7
# 29                          4.8   0.1   0.3  4.7
# 30                          1.7   0.1   0.0  1.8
# 31                          2.4   0.1   0.1  2.4
# 32                          2.1   0.1   0.1  2.2
# 33                          3.2   0.0   0.0  3.3
# 34                          3.9   0.1   0.0  4.0
# 35                          3.1   0.0   0.0  3.0
# 36                          3.8   0.1   0.0  4.1
# 37                          2.1   0.1   0.0  2.2
# 38                          3.0   0.0   0.0  2.9
# 39                          1.0   0.0   0.0  1.0
# 40                          0.6   0.0   0.0  0.7
# 41                          1.6   0.0   0.1  1.5
# 42                          1.9   0.0   0.1  1.9
# 43                          1.0   0.2   0.0  1.1
# 44                          1.5   0.1   0.1  1.5
# 45                          0.1   0.0   0.0  0.1
# 46                          0.0   0.0   0.0  0.0
# --------------------------------------------------
#
# education (%):
# cluster                                    1     2     3     4
# education
# 10th grade                               3.2   6.0   3.7   2.9
# 11th grade                               3.8   4.5   2.4   3.7
# 12th grade no diploma                    1.3   1.5   0.6   1.1
# 1st 2nd 3rd or 4th grade                 0.6   2.6   0.0   0.6
# 5th or 6th grade                         1.2   4.1   0.1   1.2
# 7th and 8th grade                        1.9  10.2   2.8   1.8
# 9th grade                                1.8   4.4   4.2   2.0
# Associates degree-academic program       3.6   1.7   0.0   3.7
# Associates degree-occup /vocational      4.2   2.3   0.1   4.1
# Bachelors degree(BA AB BS)              16.0   8.2   0.2  16.7
# Children                                 0.0   NaN  83.1   NaN
# Doctorate degree(PhD EdD)                1.0   0.5   NaN   1.1
# High school graduate                    33.1  35.7   1.0  32.4
# Less than 1st grade                      0.2   1.4   0.1   0.2
# Masters degree(MA MS MEng MEd MSW MBA)   5.1   2.6   0.0   5.5
# Prof school degree (MD DDS DVM LLB JD)   1.5   0.6   NaN   1.5
# Some college but no degree              21.4  13.9   1.7  21.4
# --------------------------------------------------
#
# enroll in edu inst last wk (%):
# cluster                        1     2     3     4
# enroll in edu inst last wk
# College or university        4.8   0.7   2.0   4.2
# High school                  2.4   0.1   8.0   2.4
# Not in universe             92.8  99.3  90.0  93.3
# --------------------------------------------------
#
# marital stat (%):
# cluster                             1     2     3     4
# marital stat
# Divorced                          9.9   7.5   0.0   9.8
# Married-A F spouse present        0.4   0.4   NaN   0.4
# Married-civilian spouse present  56.3  58.4   0.0  57.4
# Married-spouse absent             1.0   1.1   0.0   1.0
# Never married                    27.8   9.6  99.9  27.1
# Separated                         2.6   2.5   0.0   2.5
# Widowed                           1.9  20.5   0.0   1.8
# --------------------------------------------------
#
# major industry code (%):
# cluster                                 1     2     3     4
# major industry code
# Agriculture                           2.5   0.3   0.1   2.6
# Armed Forces                          0.0   0.0   0.0   0.0
# Business and repair services          5.7   0.1   0.1   5.8
# Communications                        1.1   0.0   0.0   1.2
# Construction                          5.6   0.1   0.0   5.9
# Education                             7.6   0.1   0.1   8.0
# Entertainment                         1.6   0.0   0.1   1.5
# Finance insurance and real estate     6.0   0.1   0.0   6.1
# Forestry and fisheries                0.1   0.0   0.0   0.1
# Hospital services                     3.8   0.0   0.0   3.7
# Manufacturing-durable goods           9.0   0.1   0.0   9.0
# Manufacturing-nondurable goods        6.5   0.1   0.0   6.7
# Medical except hospital               4.3   0.1   0.0   4.6
# Mining                                0.5   0.0   NaN   0.5
# Not in universe or children           6.7  98.2  98.6   4.2
# Other professional services           4.2   0.1   0.0   4.5
# Personal services except private HH   2.6   0.1   0.0   2.7
# Private household services            0.8   0.1   0.1   0.8
# Public administration                 4.2   0.1   0.0   4.6
# Retail trade                         16.4   0.2   0.6  16.3
# Social services                       2.2   0.1   0.1   2.3
# Transportation                        4.0   0.1   0.0   4.1
# Utilities and sanitary services       1.1   0.0   0.0   1.2
# Wholesale trade                       3.4   0.0   0.0   3.6
# --------------------------------------------------
#
# major occupation code (%):
# cluster                                   1     2     3     4
# major occupation code
# Adm support including clerical         14.2   0.2   0.1  14.3
# Armed Forces                            0.0   0.0   0.0   0.0
# Executive admin and managerial         11.7   0.1   0.0  12.5
# Farming forestry and fishing            2.6   0.3   0.1   2.7
# Handlers equip cleaners etc             4.0   0.1   0.2   4.0
# Machine operators assmblrs & inspctrs   5.9   0.1   0.0   6.4
# Not in universe                         6.7  98.2  98.6   4.2
# Other service                          11.1   0.3   0.5  11.2
# Precision production craft & repair    10.2   0.1   0.0  10.3
# Private household services              0.7   0.0   0.1   0.6
# Professional specialty                 13.0   0.2   0.1  13.7
# Protective services                     1.8   0.0   0.0   1.7
# Sales                                  11.2   0.1   0.2  11.6
# Technicians and related support         3.0   0.0   0.0   3.0
# Transportation and material moving      4.0   0.1   0.0   3.9
# --------------------------------------------------
#
# race (%):
# cluster                         1     2     3     4
# race
# Amer Indian Aleut or Eskimo   0.6   0.5   0.7   0.5
# Asian or Pacific Islander     2.5   2.4   2.8   2.5
# Black                        11.2  11.1  17.2  11.1
# Other                         0.8   0.7   1.7   1.2
# White                        84.8  85.3  77.6  84.7
# --------------------------------------------------
#
# hispanic origin (%):
# cluster                       1     2     3     4
# hispanic origin
# All other                  89.8  90.6  85.4  90.8
# Central or South American   1.5   1.0   1.7   1.4
# Chicano                     0.1   0.1   0.2   0.1
# Cuban                       0.4   0.6   0.3   0.4
# Do not know                 0.2   0.2   0.1   0.1
# Mexican (Mexicano)          3.0   2.9   3.4   3.3
# Mexican-American            2.7   2.1   6.2   2.4
# Missing                     0.8   0.6   0.4   0.2
# Other Spanish               0.7   0.7   0.9   0.6
# Puerto Rican                0.8   1.1   1.5   0.8
# --------------------------------------------------
#
# sex (%):
# cluster     1     2     3     4
# sex
# Female   47.0  66.2  48.7  46.7
# Male     53.0  33.8  51.3  53.3
# --------------------------------------------------
#
# member of a labor union (%):
# cluster                     1      2     3     4
# member of a labor union
# No                       15.7    0.0   0.1  16.0
# Not in universe          81.4  100.0  99.9  81.1
# Yes                       2.9    0.0   NaN   2.9
# --------------------------------------------------
#
# reason for unemployment (%):
# cluster                     1     2     3     4
# reason for unemployment
# Job leaver                0.6   0.1   0.0   0.6
# Job loser - on layoff     0.9   0.1   0.0   0.8
# New entrant               0.1   0.2   0.6   0.0
# Not in universe          94.1  99.1  99.0  95.4
# Other job loser           2.3   0.2   0.0   1.7
# Re-entrant                2.1   0.4   0.3   1.5
# --------------------------------------------------
#
# full or part time employment stat (%):
# cluster                                 1     2     3     4
# full or part time employment stat
# Children or Armed Forces            100.0  47.8  91.3   0.7
# Full-time schedules                   NaN   0.4   0.4  79.5
# Not in labor force                    NaN  51.1   7.7   4.7
# PT for econ reasons usually FT        NaN   0.0   0.0   1.0
# PT for econ reasons usually PT        NaN   0.0   0.0   2.4
# PT for non-econ reasons usually FT    NaN   0.1   0.0   6.5
# Unemployed full-time                  NaN   0.5   0.2   4.0
# Unemployed part- time                 NaN   0.1   0.4   1.2
# --------------------------------------------------
#
# tax filer stat (%):
# cluster                          1     2     3     4
# tax filer stat
# Head of household              6.6   1.2   0.0   6.9
# Joint both 65+                 1.2  17.6   NaN   1.1
# Joint both under 65           53.6  24.0   0.0  54.7
# Joint one under 65 & one 65+   1.5   5.4   0.0   1.7
# Nonfiler                       5.0  37.9  99.2   3.1
# Single                        32.1  14.0   0.8  32.5
# --------------------------------------------------
#
# region of previous residence (%):
# cluster                          1     2     3      4
# region of previous residence
# Abroad                         0.5   0.3   0.3    NaN
# Midwest                        4.7   0.6   1.7    NaN
# Northeast                      2.9   0.5   1.0    NaN
# Not in universe               79.6  96.6  92.2  100.0
# South                          7.1   1.2   2.8    NaN
# West                           5.2   0.8   1.9    NaN
# --------------------------------------------------
#
# state of previous residence (%):
# cluster                         1     2     3      4
# state of previous residence
# Abroad                        0.5   0.3   0.3    NaN
# Alabama                       0.4   0.1   0.1    NaN
# Alaska                        0.1   0.0   0.0    NaN
# Arizona                       0.4   0.1   0.2    NaN
# Arkansas                      0.2   0.0   0.1    NaN
# California                    2.9   0.4   1.1    NaN
# Colorado                      0.3   0.1   0.1    NaN
# Connecticut                   0.2   0.0   0.1    NaN
# Delaware                      0.0   0.0   0.0    NaN
# District of Columbia          0.1   0.0   0.0    NaN
# Florida                       1.2   0.3   0.5    NaN
# Georgia                       0.6   0.0   0.2    NaN
# Idaho                         0.0   0.0   0.0    NaN
# Illinois                      0.1   0.0   0.0    NaN
# Indiana                       0.8   0.1   0.2    NaN
# Iowa                          0.4   0.1   0.2    NaN
# Kansas                        0.2   0.0   0.1    NaN
# Kentucky                      0.2   0.0   0.1    NaN
# Louisiana                     0.3   0.1   0.1    NaN
# Maine                         0.3   0.0   0.1    NaN
# Maryland                      0.1   0.0   0.0    NaN
# Massachusetts                 0.3   0.0   0.1    NaN
# Michigan                      0.4   0.1   0.1    NaN
# Minnesota                     0.7   0.1   0.3    NaN
# Missing                       1.2   0.2   0.4    NaN
# Mississippi                   0.4   0.0   0.1    NaN
# Missouri                      0.2   0.0   0.1    NaN
# Montana                       0.5   0.1   0.2    NaN
# Nebraska                      0.1   0.0   0.0    NaN
# Nevada                        0.1   0.0   0.1    NaN
# New Hampshire                 0.2   0.1   0.0    NaN
# New Jersey                    0.1   0.0   0.0    NaN
# New Mexico                    0.5   0.1   0.1    NaN
# New York                      0.1   0.0   0.0    NaN
# North Carolina                1.0   0.2   0.4    NaN
# North Dakota                  0.5   0.1   0.2    NaN
# Not in universe              79.6  96.6  92.2  100.0
# Ohio                          0.1   0.0   0.0    NaN
# Oklahoma                      0.8   0.1   0.3    NaN
# Oregon                        0.3   0.0   0.1    NaN
# Pennsylvania                  0.3   0.1   0.1    NaN
# South Carolina                0.1   0.0   0.0    NaN
# South Dakota                  0.2   0.0   0.1    NaN
# Tennessee                     0.1   0.0   0.0    NaN
# Texas                         0.4   0.1   0.1    NaN
# Utah                          1.6   0.3   0.7    NaN
# Vermont                       0.1   0.0   0.1    NaN
# Virginia                      0.1   0.0   0.0    NaN
# West Virginia                 0.5   0.1   0.1    NaN
# Wisconsin                     0.1   0.0   0.0    NaN
# Wyoming                       0.5   0.1   0.1    NaN
# --------------------------------------------------
#
# detailed household and family stat (%):
# cluster                                             1     2     3     4
# detailed household and family stat
# Child 18+ ever marr Not in a subfamily            1.0   0.9   0.0   0.9
# Child 18+ ever marr RP of subfamily               0.5   0.4   0.0   0.5
# Child 18+ never marr Not in a subfamily          10.6   2.3   3.7  10.1
# Child 18+ never marr RP of subfamily              0.4   0.2   0.2   0.4
# Child 18+ spouse of subfamily RP                  0.1   0.1   NaN   0.1
# Child <18 ever marr RP of subfamily               0.0   0.0   0.0   0.0
# Child <18 ever marr not in subfamily              0.0   NaN   0.1   0.0
# Child <18 never marr RP of subfamily              0.0   NaN   0.1   0.0
# Child <18 never marr not in subfamily             1.5   NaN  85.1   1.6
# Child <18 spouse of subfamily RP                  NaN   0.0   NaN   NaN
# Child under 18 of RP of unrel subfamily           0.0   NaN   1.3   0.0
# Grandchild 18+ ever marr RP of subfamily          0.0   0.0   NaN   0.0
# Grandchild 18+ ever marr not in subfamily         0.0   0.0   NaN   0.0
# Grandchild 18+ never marr RP of subfamily         0.0   NaN   0.0   0.0
# Grandchild 18+ never marr not in subfamily        0.4   0.1   0.2   0.3
# Grandchild 18+ spouse of subfamily RP             0.0   0.0   NaN   0.0
# Grandchild <18 ever marr not in subfamily         0.0   NaN   NaN   NaN
# Grandchild <18 never marr RP of subfamily         NaN   NaN   0.0   NaN
# Grandchild <18 never marr child of subfamily RP   0.0   NaN   3.4   0.0
# Grandchild <18 never marr not in subfamily        0.0   NaN   1.9   0.0
# Householder                                      37.9  31.9   0.1  38.1
# In group quarters                                 0.1   0.1   0.1   0.1
# Nonfamily householder                            12.6  22.1   0.0  12.9
# Other Rel 18+ ever marr RP of subfamily           0.4   0.6   NaN   0.3
# Other Rel 18+ ever marr not in subfamily          0.6   3.5   NaN   0.6
# Other Rel 18+ never marr RP of subfamily          0.1   0.0   0.0   0.1
# Other Rel 18+ never marr not in subfamily         1.3   1.0   0.3   1.3
# Other Rel 18+ spouse of subfamily RP              0.4   0.5   NaN   0.4
# Other Rel <18 ever marr RP of subfamily           0.0   0.0   NaN   0.0
# Other Rel <18 ever marr not in subfamily          NaN   NaN   0.0   NaN
# Other Rel <18 never marr child of subfamily RP    0.0   NaN   1.1   0.0
# Other Rel <18 never marr not in subfamily         0.0   NaN   1.1   0.0
# Other Rel <18 never married RP of subfamily       NaN   NaN   0.0   NaN
# Other Rel <18 spouse of subfamily RP              0.0   0.0   NaN   NaN
# RP of unrelated subfamily                         0.7   0.2   0.1   0.4
# Secondary individual                              5.4   1.9   1.1   5.2
# Spouse of RP of unrelated subfamily               0.0   0.0   NaN   0.0
# Spouse of householder                            25.7  34.4   0.0  26.5
# --------------------------------------------------
#
# detailed household summary in household (%):
# cluster                                     1     2     3     4
# detailed household summary in household
# Child 18 or older                        12.6   3.8   4.0  12.0
# Child under 18 ever married               0.0   0.0   0.1   0.0
# Child under 18 never married              1.5   NaN  85.2   1.6
# Group Quarters- Secondary individual      0.1   0.1   0.0   0.0
# Householder                              50.5  53.9   0.1  51.0
# Nonrelative of householder                6.2   2.1   2.5   5.7
# Other relative of householder             3.3   5.7   8.1   3.1
# Spouse of householder                    25.7  34.4   0.0  26.5
# --------------------------------------------------
#
# migration code-change in msa (%):
# cluster                          1     2     3      4
# migration code-change in msa
# Abroad to MSA                  0.4   0.3   0.2    NaN
# Abroad to nonMSA               0.1   0.0   0.0    NaN
# MSA to MSA                    15.3   2.0   5.5    NaN
# MSA to nonMSA                  0.7   0.2   0.4    NaN
# Missing                        NaN  52.3  50.4  100.0
# NonMSA to MSA                  0.8   0.2   0.3    NaN
# NonMSA to nonMSA               2.8   0.7   1.2    NaN
# Nonmover                      79.6  44.3  39.0    NaN
# Not identifiable               0.3   0.1   0.1    NaN
# Not in universe                NaN   NaN   2.8    NaN
# --------------------------------------------------
#
# migration code-change in reg (%):
# cluster                            1     2     3      4
# migration code-change in reg
# Abroad                           0.5   0.3   0.3    NaN
# Different county same state      4.0   0.7   1.4    NaN
# Different division same region   0.5   0.1   0.2    NaN
# Different region                 1.4   0.4   0.6    NaN
# Different state same division    1.0   0.4   0.5    NaN
# Missing                          NaN  52.3  50.4  100.0
# Nonmover                        79.6  44.3  39.0    NaN
# Not in universe                  NaN   NaN   2.8    NaN
# Same county                     13.0   1.5   4.8    NaN
# --------------------------------------------------
#
# migration code-move within reg (%):
# cluster                            1     2     3      4
# migration code-move within reg
# Abroad                           0.5   0.3   0.3    NaN
# Different county same state      4.0   0.7   1.4    NaN
# Different state in Midwest       0.7   0.2   0.3    NaN
# Different state in Northeast     0.5   0.1   0.2    NaN
# Different state in South         1.2   0.3   0.5    NaN
# Different state in West          0.6   0.3   0.3    NaN
# Missing                          NaN  52.3  50.4  100.0
# Nonmover                        79.6  44.3  39.0    NaN
# Not in universe                  NaN   NaN   2.8    NaN
# Same county                     13.0   1.5   4.8    NaN
# --------------------------------------------------
#
# live in this house 1 year ago (%):
# cluster                              1     2     3      4
# live in this house 1 year ago
# No                                20.4   3.4   7.8    NaN
# Not in universe under 1 year old   NaN  52.3  53.3  100.0
# Yes                               79.6  44.3  39.0    NaN
# --------------------------------------------------
#
# migration prev res in sunbelt (%):
# cluster                           1     2     3      4
# migration prev res in sunbelt
# Missing                         NaN  52.3  50.4  100.0
# No                             12.2   2.0   4.4    NaN
# Not in universe                79.6  44.3  41.8    NaN
# Yes                             8.2   1.4   3.4    NaN
# --------------------------------------------------
#
# family members under 18 (%):
# cluster                     1      2     3     4
# family members under 18
# Both parents present      1.2    NaN  65.3   1.3
# Father only present       0.0    NaN   3.2   0.1
# Mother only present       0.3    NaN  22.5   0.3
# Neither parent present    0.1    NaN   3.0   0.1
# Not in universe          98.4  100.0   6.0  98.3
# --------------------------------------------------
#
# country of birth father (%):
# cluster                          1     2     3     4
# country of birth father
# Cambodia                       0.1   0.1   0.1   0.1
# Canada                         0.7   1.0   0.2   0.6
# China                          0.5   0.4   0.3   0.4
# Columbia                       0.2   0.2   0.2   0.2
# Cuba                           0.4   0.6   0.4   0.4
# Dominican-Republic             0.3   0.4   0.7   0.2
# Ecuador                        0.1   0.1   0.1   0.1
# El-Salvador                    0.5   0.2   0.6   0.4
# England                        0.4   0.8   0.2   0.3
# France                         0.1   0.2   0.1   0.1
# Germany                        0.5   1.5   0.3   0.6
# Greece                         0.2   0.2   0.1   0.2
# Guatemala                      0.2   0.1   0.2   0.2
# Haiti                          0.2   0.1   0.3   0.2
# Holand-Netherlands             NaN   0.0   0.0   0.1
# Honduras                       0.1   0.1   0.1   0.1
# Hong Kong                      0.1   0.0   0.1   0.0
# Hungary                        0.1   0.5   0.0   0.1
# India                          0.3   0.2   0.2   0.2
# Iran                           0.2   0.1   0.1   0.1
# Ireland                        0.2   0.5   0.0   0.2
# Italy                          0.9   3.0   0.2   0.7
# Jamaica                        0.2   0.1   0.3   0.3
# Japan                          0.1   0.3   0.1   0.1
# Laos                           0.0   0.1   0.1   0.1
# Mexico                         3.7   3.7   6.0   3.8
# Missing                        2.8   5.9   2.2   2.7
# Nicaragua                      0.1   0.1   0.1   0.1
# Outlying-U S (Guam USVI etc)   0.0   0.1   0.1   0.1
# Panama                         NaN   0.0   0.0   0.0
# Peru                           0.1   0.1   0.1   0.1
# Philippines                    0.6   0.3   0.5   0.7
# Poland                         0.4   1.6   0.1   0.5
# Portugal                       0.2   0.2   0.1   0.1
# Puerto-Rico                    0.8   1.1   1.0   0.7
# Scotland                       0.1   0.2   0.0   0.1
# South Korea                    0.2   0.3   0.3   0.2
# Taiwan                         0.1   0.1   0.1   0.1
# Thailand                       0.0   0.1   0.1   0.0
# Trinadad&Tobago                0.1   0.1   0.1   0.1
# United-States                 83.9  74.5  83.7  84.3
# Vietnam                        0.2   0.2   0.3   0.2
# Yugoslavia                     0.1   0.3   0.1   0.1
# --------------------------------------------------
#
# country of birth mother (%):
# cluster                          1     2     3     4
# country of birth mother
# Cambodia                       0.1   0.1   0.1   0.0
# Canada                         0.7   1.0   0.3   0.7
# China                          0.4   0.4   0.2   0.3
# Columbia                       0.2   0.2   0.2   0.2
# Cuba                           0.4   0.6   0.3   0.4
# Dominican-Republic             0.3   0.3   0.5   0.2
# Ecuador                        0.1   0.1   0.1   0.1
# El-Salvador                    0.5   0.3   0.6   0.4
# England                        0.5   0.7   0.2   0.5
# France                         0.1   0.2   0.1   0.1
# Germany                        0.6   1.3   0.4   0.7
# Greece                         0.1   0.2   0.1   0.1
# Guatemala                      0.2   0.1   0.2   0.2
# Haiti                          0.2   0.1   0.3   0.2
# Holand-Netherlands             NaN   0.0   0.0   0.1
# Honduras                       0.1   0.1   0.1   0.1
# Hong Kong                      0.1   0.0   0.1   0.1
# Hungary                        0.1   0.5   0.0   0.1
# India                          0.3   0.2   0.3   0.2
# Iran                           0.2   0.1   0.1   0.1
# Ireland                        0.3   0.6   0.0   0.3
# Italy                          0.7   2.6   0.2   0.6
# Jamaica                        0.2   0.2   0.2   0.3
# Japan                          0.2   0.3   0.2   0.2
# Laos                           0.0   0.1   0.1   0.1
# Mexico                         3.7   3.6   5.8   3.8
# Missing                        2.5   5.4   2.1   2.4
# Nicaragua                      0.1   0.1   0.1   0.1
# Outlying-U S (Guam USVI etc)   0.1   0.1   0.1   0.1
# Panama                         NaN   0.0   0.0   0.0
# Peru                           0.1   0.1   0.2   0.1
# Philippines                    0.6   0.4   0.7   0.7
# Poland                         0.4   1.5   0.1   0.4
# Portugal                       0.1   0.2   0.1   0.1
# Puerto-Rico                    0.7   1.1   0.8   0.6
# Scotland                       0.1   0.3   0.0   0.1
# South Korea                    0.2   0.3   0.3   0.2
# Taiwan                         0.1   0.1   0.2   0.1
# Thailand                       0.0   0.1   0.1   0.1
# Trinadad&Tobago                0.1   0.1   0.1   0.1
# United-States                 84.2  76.0  84.2  84.5
# Vietnam                        0.2   0.2   0.3   0.2
# Yugoslavia                     0.1   0.2   0.1   0.1
# --------------------------------------------------
#
# country of birth self (%):
# cluster                          1     2     3     4
# country of birth self
# Cambodia                       0.1   0.1   0.0   0.0
# Canada                         0.3   0.6   0.1   0.4
# China                          0.2   0.4   0.1   0.2
# Columbia                       0.2   0.2   0.1   0.2
# Cuba                           0.3   0.6   0.0   0.4
# Dominican-Republic             0.2   0.3   0.2   0.2
# Ecuador                        0.1   0.1   0.0   0.1
# El-Salvador                    0.4   0.2   0.2   0.4
# England                        0.3   0.4   0.1   0.3
# France                         0.1   0.1   0.0   0.1
# Germany                        0.5   0.7   0.3   0.4
# Greece                         0.1   0.1   0.0   0.1
# Guatemala                      0.2   0.1   0.1   0.2
# Haiti                          0.2   0.1   0.1   0.2
# Holand-Netherlands             NaN   0.0   0.0   0.0
# Honduras                       0.1   0.1   0.0   0.1
# Hong Kong                      0.1   0.0   0.0   0.1
# Hungary                        0.0   0.1   0.0   0.0
# India                          0.3   0.2   0.1   0.2
# Iran                           0.2   0.1   0.0   0.1
# Ireland                        0.1   0.1   0.0   0.1
# Italy                          0.2   0.5   0.0   0.2
# Jamaica                        0.2   0.1   0.1   0.3
# Japan                          0.2   0.2   0.1   0.2
# Laos                           0.0   0.1   0.0   0.1
# Mexico                         2.9   2.8   1.5   3.1
# Missing                        1.8   2.4   0.9   1.8
# Nicaragua                      0.1   0.1   0.1   0.1
# Outlying-U S (Guam USVI etc)   0.0   0.1   0.0   0.1
# Panama                         NaN   0.0   0.0   0.0
# Peru                           0.1   0.1   0.0   0.1
# Philippines                    0.5   0.3   0.2   0.6
# Poland                         0.2   0.4   0.0   0.2
# Portugal                       0.1   0.1   0.0   0.1
# Puerto-Rico                    0.5   0.8   0.2   0.4
# Scotland                       0.0   0.1   0.0   0.0
# South Korea                    0.2   0.3   0.2   0.2
# Taiwan                         0.1   0.1   0.0   0.1
# Thailand                       0.0   0.1   0.1   0.1
# Trinadad&Tobago                0.1   0.1   0.0   0.0
# United-States                 88.5  86.6  95.0  88.7
# Vietnam                        0.2   0.2   0.2   0.2
# Yugoslavia                     0.0   0.1   0.0   0.0
# --------------------------------------------------
#
# citizenship (%):
# cluster                                         1     2     3     4
# citizenship
# Foreign born- Not a citizen of U S            6.8   7.4   3.7   6.7
# Foreign born- U S citizen by naturalization   3.1   4.4   0.4   3.2
# Native- Born abroad of American Parent(s)     1.1   0.7   0.7   0.9
# Native- Born in Puerto Rico or U S Outlying   0.5   0.9   0.3   0.5
# Native- Born in the United States            88.5  86.6  95.0  88.7
# --------------------------------------------------
#
# own business or self employed (%):
# cluster                           1     2     3     4
# own business or self employed
# 0                              82.8  99.6  99.8  81.1
# 1                               2.3   0.1   0.0   2.9
# 2                              14.9   0.3   0.2  16.0
# --------------------------------------------------
#
# fill inc questionnaire for veteran's admin (%):
# cluster                                        1     2      3     4
# fill inc questionnaire for veteran's admin
# No                                           0.7   2.2    0.0   0.7
# Not in universe                             99.3  97.0  100.0  99.2
# Yes                                          0.1   0.8    0.0   0.1
# --------------------------------------------------
#
# veterans benefits (%):
# cluster               1     2     3     4
# veterans benefits
# 0                   NaN   NaN  83.1   NaN
# 1                   0.7   3.0   0.0   0.8
# 2                  99.3  97.0  16.9  99.2
# --------------------------------------------------
